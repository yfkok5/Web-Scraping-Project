# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url_2 = "https://www.myer.com.au/c/home/all-appliances?pageNumber=2"

# %%
# Use the below headers when requesting the url may help you to avoid being blocked from the site
HEADERS = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'}

#result = requests.get(url, hea)

#doc = BeautifulSoup(result.text,"html.parser")

# %%
# Get the HTML content get_url()
def get_url(url):
    try:
        response = requests.get(url,headers = HEADERS).text
        soup = BeautifulSoup(response, 'html.parser')
        return soup
    except Exception as err:
        print('ERROR BY REQUEST:', err)
        return None

# %%
get_url(url_2).prettify()[0:1000]
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="index, follow" name="robots"/>\n  <meta content="Helium" name="siteVersion"/>\n  <meta content="5CKNWS75CajAyjQ8L-NUhoD2m0sVA__3-ZhYVdCce-g" name="google-site-verification"/>\n  <script type="text/javascript">\n   ;window.NREUM||(NREUM={});NREUM.init={distributed_tracing:{enabled:true},privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]}};\nwindow.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(32),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!='

# %%
soup = get_url(url_2)

# %%
# find all the products on the page: depending on when you run it may return different number, you can cross-ref on the website
products = soup.find_all('li', {'data-automation':'product-grid-item'})
print(len(products))
# Out:
# 48

# %%
# you pick up the first product, look for the span element and the specific product price currently on display
# i used .text to extract the current price

products[1].find("span" , {"data-automation": "product-price-was"}).text
# Out:
# '$99.00'

# %%
#Creating empty list to be appended on
products_DF = []
price_was = []
price_now = []

for each_item in range(0,len(products)):

    #Extract product_list
    product_item = products[each_item].find("span" , {"data-automation": "product-name"}).text
    products_DF.append(product_item)

    #
    try:
        product_price_was = products[each_item].find("span" , {"data-automation": "product-price-was"}).text
        price_was.append(product_price_was)
    except:
        product_price_was = 'Empty'
        price_was.append('Empty')
    
    try:
        product_price_now = products[each_item].find("span" , {"data-automation": "product-price-now"}).text
        price_now.append(product_price_now)
    except:
        product_price_now = 'Empty'
        price_now.append('Empty')

d = {'Products': products_DF, 'Price Was': price_was, 'Price Now': price_now}

myer_product_df = pd.DataFrame(data=d)
myer_product_df
# Out:
#                                              Products Price Was Price Now
# 0   by Delonghi inissia & Milk Capsule Coffee Make...     Empty   $229.00
# 1                              Nutribullet Baby White    $99.00    $79.20
# 2           Artisan 9 Speed Hand Mixer Red 5KHM926AER   $199.00   $159.20
# 3   24 Litre Air Fryer Multifunctional LCD Digital...   $179.95     Empty
# 4   Kleenmaid Best Heavy Duty 12kg Top Load Washin...  $2099.00  $1699.00
# 5               The Wave Kit Hair Styler Pink SKU6000   $115.00    $92.00
# 6   2400 Watt Convector Heater with Timer White HS...   $159.00   $135.15
# 7           Mini Barista Coffee Machine Black EM4300K   $329.00   $263.20
# 8         Foodi Cold & Hot Blender Black/Silver HB150   $399.00   $319.20
# 9   Sonicare Protective Clean Electric Toothbrush ...   $109.00    $87.20
# 10  by Delonghi VertuoPlus & Milk Capsule Coffee M...   $409.00   $327.20
# 11   4.3L Touchscreen Digital Air Fryer Black FT50533   $149.00    $74.50
# 12            HD07 Supersonic Iron/Fuschia Hair Dryer   $599.00     Empty
# 13         Select Blender 1200 Dark Grey NB07200-1210   $219.00   $175.20
# 14  Sonicare Protective Clean Electric Toothbrush ...   $199.00   $159.20
# 15      Addison Stainless Steel Digital Kettle RHK510    $89.95    $71.96
# 16  PerfectCare Azur Elite Black/Blue Steam Iron G...   $199.00   $159.20
# 17  Dedica Arte Manual Pump Coffee Machine Metal E...   $489.00     Empty
# 18               Express Crock Multi Cooker XL CPE300   $199.00   $159.20
# 19  Shade Select Vertical Waffle Maker Black WAM50...   $139.00   $111.20
# 20  Nespresso Gran Lattissima Capsule Coffee Machi...   $789.00   $631.20
# 21                    Dual Zone Air Fryer Black AF300   $449.00   $359.20
# 22  Lumea Prestige IPL Hair Removal Device Rose Go...   $899.00   $719.20
# 23       Icona Capitals Sydney Kettle White KBOC2001W   $169.00   $135.20
# 24  Air Fryer Healthy Food No Oil Cooking Recipe 3...    $64.95     Empty
# 25                The Rice Box Cooker White BRC460WHT   $139.00   $111.20
# 26  Big Fill Toastie For 4 Sandwich Press Silver G...    $89.95    $71.96
# 27                 Auto-IQ Blender Black/Grey BL480NZ   $199.00   $159.20
# 28  Cafe Contact Stainless Steel Grill & Sandwich ...   $119.00    $95.20
# 29    Sonicare Cordless Power Flosser Black HX3806/33   $189.00   $151.20
# 30  Spirit Gold Sparkling Water Maker White 131171...   $129.00   $103.20
# 31     Access Steam Care Garment Steamer Black DT9120   $189.00   $151.20
# 32  Pasta Roller for Stand Mixer 3Pc Set Stainless...   $289.00   $231.20
# 33  Sonicare Diamond Clean 9000 Toothbrush White H...   $379.00   $303.20
# 34       Artisan Stand Mixer Matte Black 5KSM160PSABM     Empty   $749.00
# 35                    XXL Baking Master Kit HD9952/01    $64.95    $51.96
# 36  The Coffee & Spice Stainless Steel Grinder Bru...    $69.95    $55.96
# 37              Hot Air Brush 'n' Style Black VS8080A    $39.95    $31.96
# 38  The Air Fry Stainless Steel Compact Oven BOV86...   $599.00   $479.20
# 39              8L All-in-One Cooker Silver HD2238/72   $349.00   $279.20
# 40             White Foot Spa With Foot Brush CFB5PBA    $49.95    $39.96
# 41  The Barista Express Coffee Machine Black Sesam...     Empty   $799.00
# 42  Proluxe Salon Hair Straightener Black/Rose Gol...   $149.00   $119.20
# 43           Bread Maker Stainless Steel SD-YR2550SST   $399.00   $319.20
# 44               Immersion Blender Dark Grey NBI07110    $89.95    $71.96
# 45  Series 7000 18 in 1 Face, Hair & Body Multigro...   $209.00   $167.20
# 46  The Smart Air Purifier with Wi-Fi White LAP308WHT   $399.00   $339.15
# 47        Stainless Steel Airfryer Bake Kit HD9925/01    $49.95    $39.96

# %%
#export to csv
from pathlib import Path  
filepath = Path('..\Web-Scraping-Project\myershoplist.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
myer_product_df.to_csv(filepath)
